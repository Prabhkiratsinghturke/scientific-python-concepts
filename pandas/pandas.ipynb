# %%
import pandas as pd
stu_record={"name":['aman','gaman','raman','parry'],'id':[1,2,3,4,],'roll no':[12,13,14,15]}
a=pd.DataFrame(stu_record,)
#ab=pd.Series(stu_record).shape
print(a)
#print(a)

#d=a.shape
#print(d)
#a.to_csv('final_data.csv')
#a.to_excel('final_data1.xlsx')
#ab.to_csv('final_data2.csv')
# Out:
#    id   name  roll no
# 0   1   aman       12
# 1   2  gaman       13
# 2   3  raman       14
# 3   4  parry       15

# %%
b=a.head(2)
print(b)
# Out:
#    id   name  roll no
# 0   1   aman       12
# 1   2  gaman       13

# %%
print(a.tail(3))
# Out:
#    id   name  roll no
# 1   2  gaman       13
# 2   3  raman       14
# 3   4  parry       15

# %%
df = pd.read_csv("TechCrunchcontinentalUSA (1).csv")
print(df)
# Out:
#                permalink              company  numEmps   category  \
# 0               lifelock             LifeLock      NaN        web
# 1               lifelock             LifeLock      NaN        web
# 2               lifelock             LifeLock      NaN        web
# 3            mycityfaces          MyCityFaces      7.0        web
# 4               flypaper             Flypaper      NaN        web
# 5           infusionsoft         Infusionsoft    105.0   software
# 6                  gauto                gAuto      4.0        web
# 7         chosenlist-com       ChosenList.com      5.0        web
# 8         chosenlist-com       ChosenList.com      5.0        web
# 9                   digg                 Digg     60.0        web
# 10                  digg                 Digg     60.0        web
# 11              facebook             Facebook    450.0        web
# 12              facebook             Facebook    450.0        web
# ...

# %%
df.columns=["company","numEmps","permalink",'category','fundedDate','city','state',"raisedAmt","raisedCurrency",'round']
print(df)
# Out:
#                  company              numEmps  permalink   category  \
# 0               lifelock             LifeLock        NaN        web
# 1               lifelock             LifeLock        NaN        web
# 2               lifelock             LifeLock        NaN        web
# 3            mycityfaces          MyCityFaces        7.0        web
# 4               flypaper             Flypaper        NaN        web
# 5           infusionsoft         Infusionsoft      105.0   software
# 6                  gauto                gAuto        4.0        web
# 7         chosenlist-com       ChosenList.com        5.0        web
# 8         chosenlist-com       ChosenList.com        5.0        web
# 9                   digg                 Digg       60.0        web
# 10                  digg                 Digg       60.0        web
# 11              facebook             Facebook      450.0        web
# 12              facebook             Facebook      450.0        web
# ...

# %%
df.index=range(1,1461)
print(df)
# Out:
#                  company              numEmps  permalink   category  \
# 1               lifelock             LifeLock        NaN        web
# 2               lifelock             LifeLock        NaN        web
# 3               lifelock             LifeLock        NaN        web
# 4            mycityfaces          MyCityFaces        7.0        web
# 5               flypaper             Flypaper        NaN        web
# 6           infusionsoft         Infusionsoft      105.0   software
# 7                  gauto                gAuto        4.0        web
# 8         chosenlist-com       ChosenList.com        5.0        web
# 9         chosenlist-com       ChosenList.com        5.0        web
# 10                  digg                 Digg       60.0        web
# 11                  digg                 Digg       60.0        web
# 12              facebook             Facebook      450.0        web
# 13              facebook             Facebook      450.0        web
# ...

# %%
#import pandas as pd
#df = pd.read_csv("TechCrunchcontinentalUSA (1).csv")
#pd.DataFrame(df,'category','fundedDate','city','state',"raisedAmt","raisedCurrency",'round',"company","numEmps","permalink")

# %%
df.iloc[0]    #here 2 is index(start from 0) value it print 3rd row in the dataframe
#df.iloc[2]   
#df.iloc[-1]   #-1 means start from last
# Out:
# company           lifelock
# numEmps           LifeLock
# permalink              NaN
# category               web
# fundedDate           Tempe
# city                    AZ
# state             1-May-07
# raisedAmt          6850000
# raisedCurrency         USD
# round                    b
# Name: 1, dtype: object

# %%
#df.iloc[:,0]                 #select all rows but only 0th column
#df.iloc[:,2]                  #select all rows but only 1st column
#df.iloc[:,-1]                 #select all rows but only last column
#df.iloc[2]
# Out:
# company           lifelock
# numEmps           LifeLock
# permalink              NaN
# category               web
# fundedDate           Tempe
# city                    AZ
# state             1-Jan-08
# raisedAmt         25000000
# raisedCurrency         USD
# round                    c
# Name: 3, dtype: object

# %%
df.iloc[0:5]              #select rows from 0 to 4 ie 5 and all column
#df.iloc[0:-5]              #select rows from 0 to -5 ie last fifth and all column
# Out:
#        company      numEmps  permalink category  fundedDate city     state  \
# 1     lifelock     LifeLock        NaN      web       Tempe   AZ  1-May-07
# 2     lifelock     LifeLock        NaN      web       Tempe   AZ  1-Oct-06
# 3     lifelock     LifeLock        NaN      web       Tempe   AZ  1-Jan-08
# 4  mycityfaces  MyCityFaces        7.0      web  Scottsdale   AZ  1-Jan-08
# 5     flypaper     Flypaper        NaN      web     Phoenix   AZ  1-Feb-08
#
#    raisedAmt raisedCurrency round
# 1    6850000            USD     b
# 2    6000000            USD     a
# 3   25000000            USD     c
# 4      50000            USD  seed
# 5    3000000            USD     a

# %%
df.iloc[:,0:1]
#df.iloc[:,0:1].shape
# Out:
#                  company
# 1               lifelock
# 2               lifelock
# 3               lifelock
# 4            mycityfaces
# 5               flypaper
# 6           infusionsoft
# 7                  gauto
# 8         chosenlist-com
# 9         chosenlist-com
# 10                  digg
# 11                  digg
# 12              facebook
# 13              facebook
# 14              facebook
# 15              facebook
# 16              facebook
# 17              facebook
# 18              facebook
# 19           photobucket
# 20           photobucket
# 21             omnidrive
# 22                  geni
# 23                  geni
# 24               twitter
# 25               twitter
# 26           stumbleupon
# 27                gizmoz
# 28                gizmoz
# 29                scribd
# 30                scribd
# ...                  ...
# 1431            fyreball
# 1432      delve-networks
# 1433      delve-networks
# 1434           livemocha
# 1435  mercentcorporation
# ...

# %%
df.iloc[[0,3,6],[0,5,6]]
# Out:
#        company city     state
# 1     lifelock   AZ  1-May-07
# 4  mycityfaces   AZ  1-Jan-08
# 7        gauto   AZ  1-Jan-08

# %%
df.iloc[0:5,5:8]
# Out:
#   city     state  raisedAmt
# 1   AZ  1-May-07    6850000
# 2   AZ  1-Oct-06    6000000
# 3   AZ  1-Jan-08   25000000
# 4   AZ  1-Jan-08      50000
# 5   AZ  1-Feb-08    3000000

# %%
df.iloc[:,:3]
# Out:
#                  company              numEmps  permalink
# 1               lifelock             LifeLock        NaN
# 2               lifelock             LifeLock        NaN
# 3               lifelock             LifeLock        NaN
# 4            mycityfaces          MyCityFaces        7.0
# 5               flypaper             Flypaper        NaN
# 6           infusionsoft         Infusionsoft      105.0
# 7                  gauto                gAuto        4.0
# 8         chosenlist-com       ChosenList.com        5.0
# 9         chosenlist-com       ChosenList.com        5.0
# 10                  digg                 Digg       60.0
# 11                  digg                 Digg       60.0
# 12              facebook             Facebook      450.0
# 13              facebook             Facebook      450.0
# 14              facebook             Facebook      450.0
# 15              facebook             Facebook      450.0
# ...
